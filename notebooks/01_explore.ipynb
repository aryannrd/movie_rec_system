# %%
# 01_explore.ipynb - CORRECT ORDER

import sys
sys.path.append('../src')  # ← Do this FIRST!

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Now import your custom modules
from preprocessing import preprocess
from data_loader import load_movie_data
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[26], line 12
#       9 import seaborn as sns
#      11 # Now import your custom modules
# ---> 12 from preprocessing import preprocess
#      13 from data_loader import load_movie_data
#
# ImportError: cannot import name 'preprocess' from 'preprocessing' (/Users/aryan/movie_rec_system/notebooks/../src/preprocessing.py)

# %%
from preprocessing import preprocess
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[27], line 1
# ----> 1 from preprocessing import preprocess
#
# ImportError: cannot import name 'preprocess' from 'preprocessing' (/Users/aryan/movie_rec_system/notebooks/../src/preprocessing.py)

# %%
df = load_movie_data('/Users/aryan/movie_rec_system/data/raw/movies.csv')
preprocessor = preprocessing.MoviePreprocessor()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[24], line 2
#       1 df = load_movie_data('/Users/aryan/movie_rec_system/data/raw/movies.csv')
# ----> 2 preprocessor = preprocessing.MoviePreprocessor()
#
# AttributeError: module 'preprocessing' has no attribute 'MoviePreprocessor'
